# %%
import import_ipynb
from data_preprocessing import load_fer2013
from model_builder import build_model
import matplotlib.pyplot as plt


X_train, X_test, y_train, y_test = load_fer2013()

model = build_model()
model.summary()

history = model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test))

# Đánh giá
loss, acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {acc * 100:.2f}%")

# Lưu mô hình
model.save("emotion_recognition_model.keras")

plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Vẽ biểu đồ Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ✅ Đã đọc file thành công!
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 48, 48, 32)        320
#
#  batch_normalization_8 (Bat  (None, 48, 48, 32)        128
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_9 (Bat  (None, 24, 24, 64)        256
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 12, 12, 128)       512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 6, 6, 128)         0
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 256)               1179904
#
#  batch_normalization_11 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1276295 (4.87 MB)
# Trainable params: 1275335 (4.87 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________
# Epoch 1/30
# 449/449 [==============================] - 326s 715ms/step - loss: 1.9382 - accuracy: 0.3234 - val_loss: 1.8013 - val_accuracy: 0.3222
# Epoch 2/30
# 449/449 [==============================] - 158s 351ms/step - loss: 1.4567 - accuracy: 0.4441 - val_loss: 1.3506 - val_accuracy: 0.4868
# Epoch 3/30
# 449/449 [==============================] - 158s 351ms/step - loss: 1.3390 - accuracy: 0.4871 - val_loss: 1.3929 - val_accuracy: 0.4766
# Epoch 4/30
# 449/449 [==============================] - 157s 349ms/step - loss: 1.2723 - accuracy: 0.5194 - val_loss: 1.3482 - val_accuracy: 0.5146
# Epoch 5/30
# 449/449 [==============================] - 166s 371ms/step - loss: 1.2272 - accuracy: 0.5368 - val_loss: 1.2588 - val_accuracy: 0.5231
# Epoch 6/30
# 449/449 [==============================] - 146s 324ms/step - loss: 1.2065 - accuracy: 0.5432 - val_loss: 1.3172 - val_accuracy: 0.4875
# Epoch 7/30
# 449/449 [==============================] - 130s 289ms/step - loss: 1.1528 - accuracy: 0.5633 - val_loss: 1.1391 - val_accuracy: 0.5798
# Epoch 8/30
# 449/449 [==============================] - 130s 290ms/step - loss: 1.1236 - accuracy: 0.5760 - val_loss: 1.1803 - val_accuracy: 0.5603
# Epoch 9/30
# 449/449 [==============================] - 128s 285ms/step - loss: 1.0963 - accuracy: 0.5896 - val_loss: 1.1487 - val_accuracy: 0.5738
# Epoch 10/30
# 449/449 [==============================] - 130s 289ms/step - loss: 1.0639 - accuracy: 0.5990 - val_loss: 1.2204 - val_accuracy: 0.5506
# Epoch 11/30
# 449/449 [==============================] - 131s 292ms/step - loss: 1.0468 - accuracy: 0.6044 - val_loss: 2.2187 - val_accuracy: 0.4994
# Epoch 12/30
# 449/449 [==============================] - 131s 293ms/step - loss: 1.0154 - accuracy: 0.6186 - val_loss: 1.1748 - val_accuracy: 0.5720
# Epoch 13/30
# 449/449 [==============================] - 128s 284ms/step - loss: 1.0092 - accuracy: 0.6184 - val_loss: 1.1048 - val_accuracy: 0.5970
# Epoch 14/30
# 449/449 [==============================] - 129s 288ms/step - loss: 0.9642 - accuracy: 0.6366 - val_loss: 1.1003 - val_accuracy: 0.6049
# Epoch 15/30
# 449/449 [==============================] - 128s 286ms/step - loss: 0.9366 - accuracy: 0.6496 - val_loss: 1.1821 - val_accuracy: 0.5875
# Epoch 16/30
# 449/449 [==============================] - 129s 287ms/step - loss: 0.9165 - accuracy: 0.6585 - val_loss: 1.0771 - val_accuracy: 0.6117
# Epoch 17/30
# 449/449 [==============================] - 129s 287ms/step - loss: 0.8902 - accuracy: 0.6647 - val_loss: 1.0814 - val_accuracy: 0.6126
# Epoch 18/30
# 449/449 [==============================] - 128s 286ms/step - loss: 0.8700 - accuracy: 0.6715 - val_loss: 1.1117 - val_accuracy: 0.5996
# Epoch 19/30
# 449/449 [==============================] - 129s 287ms/step - loss: 0.8492 - accuracy: 0.6790 - val_loss: 1.0758 - val_accuracy: 0.6195
# Epoch 20/30
# 449/449 [==============================] - 128s 284ms/step - loss: 0.8321 - accuracy: 0.6876 - val_loss: 1.1564 - val_accuracy: 0.5977
# Epoch 21/30
# 449/449 [==============================] - 132s 293ms/step - loss: 0.8156 - accuracy: 0.6963 - val_loss: 1.1429 - val_accuracy: 0.6049
# Epoch 22/30
# 449/449 [==============================] - 128s 285ms/step - loss: 0.7860 - accuracy: 0.7057 - val_loss: 1.1196 - val_accuracy: 0.6155
# Epoch 23/30
# 449/449 [==============================] - 128s 285ms/step - loss: 0.7759 - accuracy: 0.7090 - val_loss: 1.0998 - val_accuracy: 0.6120
# Epoch 24/30
# 449/449 [==============================] - 129s 288ms/step - loss: 0.7567 - accuracy: 0.7165 - val_loss: 1.7108 - val_accuracy: 0.5348
# Epoch 25/30
# 449/449 [==============================] - 129s 288ms/step - loss: 0.7372 - accuracy: 0.7255 - val_loss: 1.0901 - val_accuracy: 0.6248
# Epoch 26/30
# 449/449 [==============================] - 134s 298ms/step - loss: 0.7218 - accuracy: 0.7315 - val_loss: 1.0889 - val_accuracy: 0.6275
# Epoch 27/30
# 449/449 [==============================] - 128s 285ms/step - loss: 0.7040 - accuracy: 0.7352 - val_loss: 1.1390 - val_accuracy: 0.6133
# Epoch 28/30
# 449/449 [==============================] - 131s 292ms/step - loss: 0.6911 - accuracy: 0.7428 - val_loss: 1.1074 - val_accuracy: 0.6222
# Epoch 29/30
# 449/449 [==============================] - 132s 293ms/step - loss: 0.6739 - accuracy: 0.7500 - val_loss: 1.1332 - val_accuracy: 0.6216
# Epoch 30/30
# 449/449 [==============================] - 130s 289ms/step - loss: 0.6637 - accuracy: 0.7538 - val_loss: 1.1055 - val_accuracy: 0.6282
# 225/225 [==============================] - 10s 46ms/step - loss: 1.1055 - accuracy: 0.6282
# Test accuracy: 62.82%
