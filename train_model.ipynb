# %%
import import_ipynb
from data_preprocessing import load_fer2013
from model_builder import build_model

X_train, X_test, y_train, y_test = load_fer2013()

model = build_model()
model.summary()

model.fit(X_train, y_train, epochs=30, batch_size=64, validation_data=(X_test, y_test))

# Đánh giá
loss, acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {acc * 100:.2f}%")

# Lưu mô hình
model.save("emotion_recognition_model.keras")
# Out:
# ✅ Đã đọc file thành công!
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 839047 (3.20 MB)
# Trainable params: 839047 (3.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 449/449 [==============================] - 225s 497ms/step - loss: 1.6194 - accuracy: 0.3643 - val_loss: 1.4713 - val_accuracy: 0.4299
# Epoch 2/30
# 449/449 [==============================] - 113s 252ms/step - loss: 1.4046 - accuracy: 0.4619 - val_loss: 1.3944 - val_accuracy: 0.4758
# Epoch 3/30
# 449/449 [==============================] - 77s 170ms/step - loss: 1.2957 - accuracy: 0.5075 - val_loss: 1.3295 - val_accuracy: 0.4944
# Epoch 4/30
# 449/449 [==============================] - 68s 152ms/step - loss: 1.2013 - accuracy: 0.5442 - val_loss: 1.2758 - val_accuracy: 0.5134
# Epoch 5/30
# 449/449 [==============================] - 75s 167ms/step - loss: 1.1075 - accuracy: 0.5826 - val_loss: 1.2705 - val_accuracy: 0.5212
# Epoch 6/30
# 449/449 [==============================] - 73s 163ms/step - loss: 1.0122 - accuracy: 0.6241 - val_loss: 1.2621 - val_accuracy: 0.5358
# Epoch 7/30
# 449/449 [==============================] - 70s 155ms/step - loss: 0.9114 - accuracy: 0.6616 - val_loss: 1.2760 - val_accuracy: 0.5412
# Epoch 8/30
# 449/449 [==============================] - 66s 146ms/step - loss: 0.8073 - accuracy: 0.7066 - val_loss: 1.2981 - val_accuracy: 0.5439
# Epoch 9/30
# 449/449 [==============================] - 64s 142ms/step - loss: 0.7078 - accuracy: 0.7460 - val_loss: 1.3532 - val_accuracy: 0.5385
# Epoch 10/30
# 449/449 [==============================] - 65s 146ms/step - loss: 0.6137 - accuracy: 0.7801 - val_loss: 1.4960 - val_accuracy: 0.5359
# Epoch 11/30
# 449/449 [==============================] - 67s 150ms/step - loss: 0.5194 - accuracy: 0.8189 - val_loss: 1.5944 - val_accuracy: 0.5400
# Epoch 12/30
# 449/449 [==============================] - 71s 159ms/step - loss: 0.4261 - accuracy: 0.8526 - val_loss: 1.7529 - val_accuracy: 0.5341
# Epoch 13/30
# 449/449 [==============================] - 60s 133ms/step - loss: 0.3494 - accuracy: 0.8836 - val_loss: 1.9014 - val_accuracy: 0.5327
# Epoch 14/30
# 449/449 [==============================] - 61s 136ms/step - loss: 0.2826 - accuracy: 0.9065 - val_loss: 2.1020 - val_accuracy: 0.5369
# Epoch 15/30
# 449/449 [==============================] - 61s 136ms/step - loss: 0.2240 - accuracy: 0.9270 - val_loss: 2.3380 - val_accuracy: 0.5327
# Epoch 16/30
# 449/449 [==============================] - 60s 134ms/step - loss: 0.1721 - accuracy: 0.9478 - val_loss: 2.5351 - val_accuracy: 0.5352
# Epoch 17/30
# 449/449 [==============================] - 61s 137ms/step - loss: 0.1449 - accuracy: 0.9559 - val_loss: 2.6920 - val_accuracy: 0.5341
# Epoch 18/30
# 449/449 [==============================] - 62s 139ms/step - loss: 0.1208 - accuracy: 0.9652 - val_loss: 2.9181 - val_accuracy: 0.5291
# Epoch 19/30
# 449/449 [==============================] - 60s 134ms/step - loss: 0.1048 - accuracy: 0.9707 - val_loss: 3.1106 - val_accuracy: 0.5313
# Epoch 20/30
# 449/449 [==============================] - 62s 139ms/step - loss: 0.0869 - accuracy: 0.9761 - val_loss: 3.1773 - val_accuracy: 0.5302
# Epoch 21/30
# 449/449 [==============================] - 60s 134ms/step - loss: 0.0906 - accuracy: 0.9745 - val_loss: 3.3958 - val_accuracy: 0.5283
# Epoch 22/30
# 449/449 [==============================] - 66s 146ms/step - loss: 0.0891 - accuracy: 0.9731 - val_loss: 3.4756 - val_accuracy: 0.5231
# Epoch 23/30
# 449/449 [==============================] - 61s 137ms/step - loss: 0.0770 - accuracy: 0.9797 - val_loss: 3.6348 - val_accuracy: 0.5235
# Epoch 24/30
# 449/449 [==============================] - 59s 132ms/step - loss: 0.0729 - accuracy: 0.9814 - val_loss: 3.7466 - val_accuracy: 0.5337
# Epoch 25/30
# 449/449 [==============================] - 65s 144ms/step - loss: 0.0746 - accuracy: 0.9784 - val_loss: 3.7373 - val_accuracy: 0.5195
# Epoch 26/30
# 449/449 [==============================] - 64s 144ms/step - loss: 0.0614 - accuracy: 0.9828 - val_loss: 3.9969 - val_accuracy: 0.5238
# Epoch 27/30
# 449/449 [==============================] - 64s 143ms/step - loss: 0.0646 - accuracy: 0.9822 - val_loss: 4.0001 - val_accuracy: 0.5234
# Epoch 28/30
# 449/449 [==============================] - 66s 146ms/step - loss: 0.0643 - accuracy: 0.9823 - val_loss: 4.0320 - val_accuracy: 0.5322
# Epoch 29/30
# 449/449 [==============================] - 66s 146ms/step - loss: 0.0593 - accuracy: 0.9839 - val_loss: 4.2520 - val_accuracy: 0.5267
# Epoch 30/30
# 449/449 [==============================] - 68s 151ms/step - loss: 0.0515 - accuracy: 0.9873 - val_loss: 4.2630 - val_accuracy: 0.5286
# 225/225 [==============================] - 5s 23ms/step - loss: 4.2630 - accuracy: 0.5286
# Test accuracy: 52.86%
